# %% [markdown]
# # TEXT SPLITTING DOCUMENT

# %% [markdown]
# ## RecursiveCharacter Text Splitters

# %%
#pdf data
from langchain_community.document_loaders import PyPDFLoader
docLoader = PyPDFLoader("./data/Evansetal.2023SubsidyRemoval.pdf")
loadeddoc = docLoader.load()
loadeddoc
# Out:
# [Document(metadata={'source': './data/Evansetal.2023SubsidyRemoval.pdf', 'page': 0, 'page_label': '1'}, page_content='See discussions, stats, and author profiles for this publication at: https://www.researchgate.net/publication/373292648\nThe socio-economics of the 2023 fuel subsidy removal in Nigeria\nArticle · January 2023\nCITATIONS\n2\nREADS\n416\n6 authors, including:\nOlaniyi Evans\nPan Atlantic University\n107 PUBLICATIONS\xa0\xa0\xa01,767 CITATIONS\xa0\xa0\xa0\nSEE PROFILE\nOlusegun Vincent\nPan-Atlantic University\n22 PUBLICATIONS\xa0\xa0\xa0189 CITATIONS\xa0\xa0\xa0\nSEE PROFILE\nEkundayo Mesagan\nPan-Atlantic University\n68 PUBLICATIONS\xa0\xa0\xa0914 CITATIONS\xa0\xa0\xa0\nSEE PROFILE\nAll content following this page was uploaded by Olaniyi Evans on 22 August 2023.\nThe user has requested enhancement of the downloaded file.'),
# ...

# %%
loadeddoc[5]
# Out:
# Document(metadata={'source': './data/Evansetal.2023SubsidyRemoval.pdf', 'page': 5, 'page_label': '6'}, page_content="16       EVANS ET AL.  \n \nand its reinforcement through \nrevenue recycling \neffective revenue recycling \nmechanisms \nHarring et al. \n(2023b) \nInvestigate cross -national \nattitudes towards fossil fuel \nsubsidy removal \nCross-national \nsurvey and analysis \nAttitudes towards subsidy \nremoval are influenced by \nsocio-economic factors and \nenergy transition context \nGreve and Lay \n(2023) \nAssess the impacts of fossil fuel \nsubsidy removal in a \ndeveloping country \nDynamic general \nequilibrium model \nSubsidy removal can affect \nconsumption patterns,  GDP, \nand welfare, with varying \nimpacts on different income \ngroups \n \n3 Theoretical Framework \nAnalysing the removal of subsidies involves the application of diverse theoretical frameworks that encompass economic, \npolitical, and social dimensions. These framew orks provide valuable insights in
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=50)
final_doc = text_splitter.split_documents(loadeddoc)
final_doc
# Out:
# [Document(metadata={'source': './data/Evansetal.2023SubsidyRemoval.pdf', 'page': 0, 'page_label': '1'}, page_content='See discussions, stats, and author profiles for this publication at: https://www.researchgate.net/publication/373292648\nThe socio-economics of the 2023 fuel subsidy removal in Nigeria'),
#  Document(metadata={'source': './data/Evansetal.2023SubsidyRemoval.pdf', 'page': 0, 'page_label': '1'}, page_content='Article · January 2023\nCITATIONS\n2\nREADS\n416\n6 authors, including:\nOlaniyi Evans\nPan Atlantic University\n107 PUBLICATIONS\xa0\xa0\xa01,767 CITATIONS\xa0\xa0\xa0\nSEE PROFILE\nOlusegun Vincent\nPan-Atlantic University'),
#  Document(metadata={'source': './data/Evansetal.2023SubsidyRemoval.pdf', 'page': 0, 'page_label': '1'}, page_content='Olusegun Vincent\nPan-Atlantic University\n22 PUBLICATIONS\xa0\xa0\xa0189 CITATIONS\xa0\xa0\xa0\nSEE PROFILE\nEkundayo Mesagan\nPan-Atlantic University\n68 PUBLICATIONS\xa0\xa0\xa0914 CITATIONS\xa0\xa0\xa0\nSEE PROFILE'),
# ...

# %%
final_doc[6].page_content
# Out:
# '2,6 Dept. of Economics, University of Lagos, Lagos. \n \nThe socio-economics of the 2023 fuel subsidy \nremoval in Nigeria'

# %%
len(final_doc[6].page_content)
# Out:
# 119

# %%
len(final_doc)
# Out:
# 889

# %%
#TEXT DATA
from langchain_community.document_loaders import TextLoader
textload = TextLoader("./data/speech.txt")
speech = textload.load()
speech
# Out:
# [Document(metadata={'source': './data/speech.txt'}, page_content="Hello!\nMy name is Toheebat, and I am excited to be a learner for this program, Generative AI.\n\n\nI am a Data Scientist, aspiring Open-source Contributor, and Generative AI enthusiast with hands-on-project in the tech industry. For my career, Iâ€™m looking forward to build innovative products, solve real-world problems, and empower over 5,000 individuals to grow into better versions of themselves. My work and insights will also connect me with an audience of over 10,000 followers across social media platforms.\nLooking ahead, my vision is to create groundbreaking projects and support millionsâ€”if not billionsâ€”of people in achieving their goals and thriving in the tech industry.\n\n\nIn this program, I am here to be guided of every step I take on the way, ensuring I have an unforgettable learning experience.\nI'm embarking on this transformative journey with my peers!")]

# %%
speech_read = ""
with open("./data/speech.txt") as file:
    speech_read = file.read()
speech_read
# Out:
# "Hello!\nMy name is Toheebat, and I am excited to be a learner for this program, Generative AI.\n\n\nI am a Data Scientist, aspiring Open-source Contributor, and Generative AI enthusiast with hands-on-project in the tech industry. For my career, Iâ€™m looking forward to build innovative products, solve real-world problems, and empower over 5,000 individuals to grow into better versions of themselves. My work and insights will also connect me with an audience of over 10,000 followers across social media platforms.\nLooking ahead, my vision is to create groundbreaking projects and support millionsâ€”if not billionsâ€”of people in achieving their goals and thriving in the tech industry.\n\n\nIn this program, I am here to be guided of every step I take on the way, ensuring I have an unforgettable learning experience.\nI'm embarking on this transformative journey with my peers!"

# %%
text_splitter1 = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=50)
final_doc1 = text_splitter1.create_documents([speech_read])
final_doc1
# Out:
# [Document(metadata={}, page_content='Hello!\nMy name is Toheebat, and I am excited to be a learner for this program, Generative AI.'),
#  Document(metadata={}, page_content='I am a Data Scientist, aspiring Open-source Contributor, and Generative AI enthusiast with hands-on-project in the tech industry. For my career, Iâ€™m looking forward to build innovative products,'),
#  Document(metadata={}, page_content='looking forward to build innovative products, solve real-world problems, and empower over 5,000 individuals to grow into better versions of themselves. My work and insights will also connect me with'),
#  Document(metadata={}, page_content='My work and insights will also connect me with an audience of over 10,000 followers across social media platforms.'),
#  Document(metadata={}, page_content='Looking ahead, my vision is to create groundbreaking projects and support millionsâ€”if not billionsâ€”of people in achieving their goals and thriving in the tech industry.'),
# ...

# %%
len(final_doc1[0].page_content)
# Out:
# 93
